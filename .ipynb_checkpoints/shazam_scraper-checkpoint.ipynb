# %%
# importing libraries
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

import requests
import time
import csv

# %%
# scraping Shazam's Top 200 weekly songs in the U.S.
# function for song title, artist, rank and partial URL
def get_song_urls(chart_url):
    hdr = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    page = requests.get(chart_url, headers=hdr)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    song_list = []
    
    # find all song containers
    songs = soup.find_all('a', class_='ContainerLink-module_containerLinkElement__EOJ6S')
    
    rank = 1
    for song in songs:
        # extract song title from aria-label attribute
        song_title = song.get('aria-label')
        
        # extract partial URL
        partial_url = song.get('href')
        
        # for artist name, we need to find it in nearby elements
        artist_container = song.find_next('a', attrs={'data-test-id': 'charts_userevent_list_artistName'})
        song_artist = artist_container.text if artist_container else "Unknown Artist"
        
        # add to song list
        song_list.append(f"{rank}. {song_title} by {song_artist}. Partial url: {partial_url}")
        
        rank += 1
    
    # open and write to file
    file = open('songs.txt', 'w', encoding='utf-8')
    for song_info in song_list:
        file.write(song_info + '\n')
    file.close()
    
    return song_list

# call the function 
get_song_urls('https://www.shazam.com/charts/top-200/united-states')
# Out:
# ['1. ANXIETY (feat. Doechii) by Sleepy Hallow. Partial url: /song/1706412053/anxiety-feat-doechii',
#  '2. luther by Kendrick Lamar & SZA. Partial url: /song/1781270323/luther',
#  '3. NOKIA by Drake. Partial url: /song/1796127375/nokia',
#  '4. Messy by Lola Young. Partial url: /song/1743250261/messy',
#  '5. Anxiety by Doechii. Partial url: /song/1800052074/anxiety',
#  '6. APT. by ROSÉ & Bruno Mars. Partial url: /song/1771105935/apt',
#  '7. Die With A Smile by Lady Gaga & Bruno Mars. Partial url: /song/1792667027/die-with-a-smile',
#  '8. Ordinary by Alex Warren. Partial url: /song/1793663645/ordinary',
#  '9. DENIAL IS A RIVER by Doechii. Partial url: /song/1763934447/denial-is-a-river',
#  '10. 30 For 30 (with Kendrick Lamar) by SZA. Partial url: /song/1786643047/30-for-30-with-kendrick-lamar',
#  '11. ACTIN UP by Tommy Richman. Partial url: /song/1792976782/actin-up',
#  '12. Timeless by The Weeknd & Playboi Carti. Partial url: /song/1793654640/timeless',
#  '13. SOMEBODY LOVES ME by PARTYNEXTDOOR & Drake. Partial url: /song/1796127378/somebody-loves-me',
#  '14. That’s So True by Gracie Abrams. Partial url: /song/1775581103/thats-so-true',
#  '15. Pink Pony Club by Chappell Roan. Partial url: /song/1698723327/pink-pony-club',
#  '16. Beautiful Things by Benson Boone. Partial url: /song/1736051619/beautiful-things',
#  '17. Proud Of Me by Fridayy & Meek Mill. Partial url: /song/1792545970/proud-of-me',
#  '18. tv off (feat. Lefty Gunplay) by Kendrick Lamar. Partial url: /song/1781270540/tv-off-feat-lefty-gunplay',
#  '19. Lose Control by Teddy Swims. Partial url: /song/1691699836/lose-control',
#  '20. Scared (Sped Up) by Bushy B. Partial url: /song/1799300928/scared-sped-up',
#  '21. Somebody That I Used to Know (feat. Kimbra) by Gotye. Partial url: /song/1440754487/somebody-that-i-used-to-know-feat-kimbra',
#  '22. GIMME A HUG by Drake. Partial url: /song/1796127367/gimme-a-hug',
#  '23. ME JALO by Fuerza Regida & Grupo Frontera. Partial url: /song/1786262012/me-jalo',
#  "24. when the party's over by Billie Eilish. Partial url: /song/1450695872/when-the-partys-over",
#  '25. Not Like Us by Kendrick Lamar. Partial url: /song/1744776167/not-like-us',
#  '26. Bad Dreams by Teddy Swims. Partial url: /song/1771020950/bad-dreams',
#  '27. Headlock by Imogen Heap. Partial url: /song/1785686644/headlock',
#  '28. Where Do We Go From Here (feat. Menahan Street Band) by Charles Bradley. Partial url: /song/1485008299/where-do-we-go-from-here-feat-menahan-street-band',
#  '29. Love Somebody by Morgan Wallen. Partial url: /song/1773342229/love-somebody',
#  '30. Spitting Off the Edge of the World (feat. Perfume Genius) by Yeah Yeah Yeahs. Partial url: /song/1623183246/spitting-off-the-edge-of-the-world-feat-perfume-genius',
#  '31. Sailor Song by Gigi Perez. Partial url: /song/1770187510/sailor-song',
#  '32. Cry For Me by The Weeknd. Partial url: /song/1795692222/cry-for-me',
#  '33. Abracadabra by Lady Gaga. Partial url: /song/1792667005/abracadabra',
#  '34. WHIM WHAMIEE by PLUTO & YKNIECE. Partial url: /song/1795172481/whim-whamiee',
#  '35. Staring at the Sun by TV on the Radio. Partial url: /song/17804453/staring-at-the-sun',
#  '36. Stargazing by Myles Smith. Partial url: /song/1775728718/stargazing',
#  '37. squabble up by Kendrick Lamar. Partial url: /song/1781270321/squabble-up',
#  '38. BIRDS OF A FEATHER by Billie Eilish. Partial url: /song/1739659142/birds-of-a-feather',
#  '39. DtMF by Bad Bunny. Partial url: /song/1787023936/dtmf',
#  '40. A Bar Song (Tipsy) by Shaboozey. Partial url: /song/1737085899/a-bar-song-tipsy',
#  '41. Sports car by Tate McRae. Partial url: /song/1779319634/sports-car',
#  '42. BMF by SZA. Partial url: /song/1786643049/bmf',
#  '43. 1 AM by Civ. Partial url: /song/1792178254/1-am',
#  '44. Stand By Me (Live at The Print Shop) by Stephen Wilson Jr.. Partial url: /song/1779968618/stand-by-me-live-at-the-print-shop',
#  '45. Trap Queen by Fetty Wap. Partial url: /song/1039538355/trap-queen',
#  '46. MUTT (REMIX) by Leon Thomas & Freddie Gibbs. Partial url: /song/1765022225/mutt-remix',
#  "47. Let's Groove by Earth, Wind & Fire. Partial url: /song/523229275/lets-groove",
#  '48. Residuals by Chris Brown. Partial url: /song/1740198050/residuals',
#  '49. I Never Lie by Zach Top. Partial url: /song/1728077717/i-never-lie',
#  '50. Are You Even Real by Teddy Swims & GIVĒON. Partial url: /song/1771020952/are-you-even-real',
#  '51. Fire Woman by The Cult. Partial url: /song/1028832843/fire-woman',
#  '52. Little Things by Ella Mai. Partial url: /song/1777272259/little-things',
#  '53. Te Quería Ver by Alemán & Neton Vega. Partial url: /song/1789586108/te-quer%C3%ADa-ver',
#  '54. Too Sweet by Hozier. Partial url: /song/1775781106/too-sweet',
#  "55. I'm The Problem by Morgan Wallen. Partial url: /song/1792812019/im-the-problem",
#  '56. We Are The People by Empire Of The Sun. Partial url: /song/1713302851/we-are-the-people',
#  '57. Fat Juicy & Wet by Sexyy Red & Bruno Mars. Partial url: /song/1789858333/fat-juicy-and-wet',
#  '186. Family Affair by Mary J. Blige. Partial url: /song/1440817530/family-affair',
#  '187. Calm Down by Rema. Partial url: /song/1614063459/calm-down',
#  '188. Mo Chicken (feat. French Montana) by Bossman Dlow. Partial url: /song/1783609639/mo-chicken-feat-french-montana',
#  '189. Born Again (feat. Doja Cat & RAYE) by LISA. Partial url: /song/1798585118/born-again-feat-doja-cat-and-raye',
#  '190. Stereo Love by Edward Maya & Vika Jigulina. Partial url: /song/351996354/stereo-love',
#  '191. MILLION DOLLAR BABY (VHS) by Tommy Richman. Partial url: /song/1749616874/million-dollar-baby-vhs',
#  '192. Yo Soy Tu Maestro by Los Telez. Partial url: /song/1086652276/yo-soy-tu-maestro',
#  '193. El Gigante De Hierro by Grupo Soñador. Partial url: /song/1088454743/el-gigante-de-hierro',
#  '194. Fade into You by Mazzy Star. Partial url: /song/1440848810/fade-into-you',
#  '195. Agora Hills by Doja Cat. Partial url: /song/1707932017/agora-hills',
#  "196. Sweet Child O' Mine by Guns N' Roses. Partial url: /song/1377813701/sweet-child-o-mine",
#  '197. Everybody Loves The Sunshine by Roy Ayers Ubiquity. Partial url: /song/1435155442/everybody-loves-the-sunshine',
#  "198. we can't be friends (wait for your love) by Ariana Grande. Partial url: /song/1725878242/we-cant-be-friends-wait-for-your-love",
#  '199. Friends Like That (feat. Jason Aldean) by John Morgan. Partial url: /song/1786449845/friends-like-that-feat-jason-aldean',
#  '200. Outfit by Lil Baby & 21 Savage. Partial url: /song/1786672873/outfit']

# %%
# begin scraping featured in section for each song
    
def get_featured_in(song_url):
    hdr = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    
    
    # setup browser driver to run headless
    browser_options = Options()
    browser_options.add_argument("--headless")
    driver = webdriver.Chrome(options=browser_options)

    
    soup = None
   
    try:
        # get song page
        driver.get(song_url)
        
        time.sleep(3) 
        
        # get the html 
        page = driver.page_source
        
        # close the driver
        driver.quit()

        soup = BeautifulSoup(page, 'html.parser')
        # soup = BeautifulSoup(page.text, 'html.parser')
        
        # focuses the search area to the "Featured In" section
        soup = soup.find('div', class_='PageGrid-module_content__Ek7uQ SongPageContent_grayBg__Gv7kq')
    
             
        # find all items in the "Featured In" section
        featured_items = []
       
        # locate the featured section
        for item in soup.find_all('div', class_='MedialistInner-module_child__P5BSj'):
            # extract type (ALBUM/PLAYLIST)
            item_type = item.find('span', class_='AlbumItem-module_isPlaylistLabel__sljzV')
            item_type = item_type.text.strip() if item_type else "Unknown Type"
          
            # extract the title of the album or playlist
            item_title = item.find('span', class_='Text-module_text-black__mkuUo')
            item_title = item_title.text.strip() if item_title else "Unknown Title"
           
            # extract the owner/creator of the album or playlist
            item_owner = item.find('span', class_='Text-module_text-gray-900__Qcj0F Text-module_fontFamily__cQFwR AlbumItem-module_creatorLabel__5YY3L Text-post-module_size-base__o144k Text-module_fontWeightNormal__kB6Wg Text-module_textOverflowEllipsis__J7BCo')
            item_owner = item_owner.text.strip() if item_owner else "Unknown Owner"
           
            # append the extracted data to the list
            featured_items.append({
                'type': item_type,
                'title': item_title,
                'owner': item_owner
            })
       
        return featured_items
   
    except Exception as e:
        print(f"Error scraping {song_url}: {e}")
        return []

def scrape_shazam_top_200():
    # setup
    url = 'https://www.shazam.com/charts/top-200/united-states'
    hdr = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
   
    # get main page
    page = requests.get(url, headers=hdr)
    soup = BeautifulSoup(page.text, 'html.parser')
   
    # open CSV file
    file = open('songs.csv', 'w', newline='', encoding='utf-8')
    writer = csv.writer(file)
    writer.writerow(['Rank', 'Title', 'Artist', 'URL', 'Featured Type', 'Featured Title', 'Featured Owner'])
   

    songs = soup.find_all('a', class_='ContainerLink-module_containerLinkElement__EOJ6S')
    rank = 1
   
    for song in songs[:200]:
        title = song.get('aria-label')
        partial_url = song.get('href')
        full_url = f"https://www.shazam.com{partial_url}"
        artist_container = song.find_next('a', attrs={'data-test-id': 'charts_userevent_list_artistName'})
        artist = artist_container.text if artist_container else "Unknown Artist"
       
        print(f"Scraping {rank}: {title}")
       
        # get featured in data
        featured_items = get_featured_in(full_url)
       
        if featured_items:
            for item in featured_items:
                writer.writerow([rank, title, artist, full_url, item['type'], item['title'], item['owner']])
        else:
            writer.writerow([rank, title, artist, full_url, "", "", ""])
       
        rank += 1
        time.sleep(1)  # give it a sec to run
   
    file.close()
    print("Finished scraping. Check songs.csv for results.")

# run
scrape_shazam_top_200()
# Out:
# Processing 1: ANXIETY (feat. Doechii)
# Processing 2: luther
# Processing 3: NOKIA
# Processing 4: Messy
# Processing 5: Anxiety
# Processing 6: APT.
# Processing 7: Die With A Smile
# Processing 8: Ordinary
# Processing 9: DENIAL IS A RIVER
# Processing 10: 30 For 30 (with Kendrick Lamar)
# Processing 11: ACTIN UP
# Processing 12: Timeless
# Processing 13: SOMEBODY LOVES ME
# Processing 14: That’s So True
# Processing 15: Pink Pony Club
# Processing 16: Beautiful Things
# Processing 17: Proud Of Me
# Processing 18: tv off (feat. Lefty Gunplay)
# Processing 19: Lose Control
# Processing 20: Scared (Sped Up)
# Processing 21: Somebody That I Used to Know (feat. Kimbra)
# Processing 22: GIMME A HUG
# Processing 23: ME JALO
# Processing 24: when the party's over
# Processing 25: Not Like Us
# Processing 26: Bad Dreams
# Processing 27: Headlock
# Processing 28: Where Do We Go From Here (feat. Menahan Street Band)
# Processing 29: Love Somebody
# Processing 30: Spitting Off the Edge of the World (feat. Perfume Genius)
# Processing 31: Sailor Song
# Processing 32: Cry For Me
# Processing 33: Abracadabra
# Processing 34: WHIM WHAMIEE
# Processing 35: Staring at the Sun
# Processing 36: Stargazing
# Processing 37: squabble up
# Processing 38: BIRDS OF A FEATHER
# Processing 39: DtMF
# Processing 40: A Bar Song (Tipsy)
# Processing 41: Sports car
# Processing 42: BMF
# Processing 43: 1 AM
# Processing 44: Stand By Me (Live at The Print Shop)
# Processing 45: Trap Queen
# Processing 46: MUTT (REMIX)
# Processing 47: Let's Groove
# Processing 48: Residuals
# Processing 49: I Never Lie
# Processing 50: Are You Even Real
# Processing 51: Fire Woman
# Processing 52: Little Things
# Processing 53: Te Quería Ver
# Processing 54: Too Sweet
# Processing 55: I'm The Problem
# Processing 56: We Are The People
# Processing 57: Fat Juicy & Wet
# Processing 58: Loco
# Processing 59: The Days (NOTION Remix)
# Processing 60: Use Somebody
# Processing 61: Bad Bih 4 Ya (feat. Boston Richey)
# Processing 62: El Mayor De Los Ranas
# Processing 63: High Road
# Processing 64: Forever Ever (feat. Young Thug & Reese LAFLARE)
# Processing 65: Bed Chem
# Processing 66: Good News
# Processing 67: Good Luck, Babe!
# Processing 68: Boots on the Ground
# Processing 69: I Had Some Help (feat. Morgan Wallen)
# Processing 70: En Privado
# Processing 71: No One Noticed
# Processing 72: Tweaker
# Processing 73: Champagne Coast (feat. Blood Orange)
# Processing 74: Another Day In Paradise
# Processing 75: BAILE INoLVIDABLE
# Processing 76: Liar
# Processing 77: We Hug Now
# Processing 78: Ain't I (feat. Young Dro & T.I.)
# Processing 79: PUSH 2 START
# Processing 80: She Will
# Processing 81: DIE TRYING
# Processing 82: Get Jiggy
# Processing 83: NUEVAYoL
# Processing 84: The Largest
# Processing 85: Sorry I'm Here For Someone Else
# Processing 86: Your Love
# Processing 87: มันแปลกดีนะ
# Processing 88: Gata Only
# Processing 89: peekaboo (feat. AzChike)
# Processing 90: Espresso
# Processing 91: Heart Of A Woman
# Processing 92: I'm Gonna Love You
# Processing 93: Mi Vida Mi Muerte
# Processing 94: Show Me Love
# Processing 95: TATTOO
# Processing 96: All The Stars
# Processing 97: One Last Breath
# Processing 98: Morena
# Processing 99: Twerkin Wit Ya Friends
# Processing 100: Beanie
# Processing 101: Smells Like Teen Spirit
# Processing 102: Like Him (feat. Lola Young)
# Processing 103: Memories
# Processing 104: MUTT
# Processing 105: Hard Fought Hallelujah
# Processing 106: TWENTIES
# Processing 107: ILBB2 (feat. GloRilla)
# Processing 108: worst behaviour (feat. Kehlani)
# Processing 109: Lovehate Thing (feat. Sam Dew)
# Processing 110: Tokicha
# Processing 111: WILDFLOWER
# Processing 112: Iris
# Processing 113: Dum, Dumb, and Dumber
# Processing 114: 'Bout It
# Processing 115: SOS (Sex on Sight)
# Processing 116: Bing Bong
# Processing 117: No Pole
# Processing 118: The Door
# Processing 119: Let Me Know (feat. Future)
# Processing 120: Tom Tom
# Processing 121: WHATCHU KNO ABOUT ME
# Processing 122: Indigo
# Processing 123: Azul
# Processing 124: cLOUDs
# Processing 125: 4X4
# Processing 126: What's Up?
# Processing 127: Worst Way
# Processing 128: I Can't Make You Love Me
# Processing 129: Bitter Sweet Symphony
# Processing 130: 요단강
# Processing 131: Careless Whisper
# Processing 132: weren't for the wind
# Processing 133: Feel It (From The Original Series “Invincible”)
# Processing 134: HIM ALL ALONG
# Processing 135: Knockin' on Heaven's Door (Heretic Original Soundtrack)
# Processing 136: Here We Go (Uh Oh)
# Processing 137: Sparks
# Processing 138: EoO
# Processing 139: PA QUE LO BAILES
# Processing 140: For a Day Like Today
# Processing 141: you look like you love me
# Processing 142: BUSS AT YOU
# Processing 143: Si Antes Te Hubiera Conocido
# Processing 144: i
# Processing 145: Am I Okay?
# Processing 146: Texas
# Processing 147: Amor
# Processing 148: Da Problem Solva
# Processing 149: can't slow down
# Processing 150: Bad (feat. Tiara Thomas)
# Processing 151: Taste
# Processing 152: Don't Stop Believin'
# Processing 153: La Plena (W Sound 05)
# Processing 154: Dreams
# Processing 155: Love Me Not
# Processing 156: Everybody Wants To Rule The World
# Processing 157: Walking On A Dream
# Processing 158: Take On Me
# Processing 159: Doot Doot (6 7)
# Processing 160: Since U Been Gone
# Processing 161: Every Breath You Take
# Processing 162: Ride Or Die, Pt. 2 (feat. Villano Antillano & Tokischa)
# Processing 163: Mr. Brightside
# Processing 164: chess (slowed)
# Processing 165: Return of the Mack
# Processing 166: Like That
# Processing 167: Kids
# Processing 168: How You Remind Me
# Processing 169: Unchained Melody
# Processing 170: Help Me
# Processing 171: Bring Me to Life
# Processing 172: Siesta Freestyle
# Processing 173: Three Six Five
# Processing 174: Superpowers
# Processing 175: Sticky (feat. GloRilla, Sexyy Red & Lil Wayne)
# Processing 176: Hey Abanibee
# Processing 177: Yeah! (feat. Lil Jon & Ludacris)
# Processing 178: Don't Dream It's Over
# Processing 179: El Mayor de los Ranas (En Vivo)
# Processing 180: Austin (Boots Stop Workin')
# Processing 181: Giannis
# Processing 182: Call Me When You Break Up
# Processing 183: Until I Found You (Em Beihold Version)
# Processing 184: Have You Ever Seen The Rain
# Processing 185: RED HAIR
# Processing 186: Family Affair
# Processing 187: Calm Down
# Processing 188: Mo Chicken (feat. French Montana)
# Processing 189: Born Again (feat. Doja Cat & RAYE)
# Processing 190: Stereo Love
# Processing 191: MILLION DOLLAR BABY (VHS)
# Processing 192: Yo Soy Tu Maestro
# Processing 193: El Gigante De Hierro
# Processing 194: Fade into You
# Processing 195: Agora Hills
# Processing 196: Sweet Child O' Mine
# Processing 197: Everybody Loves The Sunshine
# Processing 198: we can't be friends (wait for your love)
# Processing 199: Friends Like That (feat. Jason Aldean)
# Processing 200: Outfit
# Done! Check songs.csv for results.

# %%
#putting songs.txt and songs.csv files into one .txt file
def create_sectioned_text_file():
    # read songs.txt
    songs_data = []
    txt_file = open('songs.txt', 'r', encoding='utf-8')
    songs_section = txt_file.read()
    txt_file.close()
    
    # read songs.csv
    features_data = []
    csv_file = open('songs.csv', 'r', encoding='utf-8')
    reader = csv.reader(csv_file)
    
    # convert CSV to text format
    features_section = ""
    for i, row in enumerate(reader):
        features_section += "\t".join(row) + "\n"
    csv_file.close()
    
    # xreate combined text file with sections
    output_file = open('shazam_data.txt', 'w', encoding='utf-8')
    
    # write songs section
    output_file.write("=" * 80 + "\n")
    output_file.write("Section: Shazam's Weekly Top 200 U.S. Songs as of 3/10/2025 \n")
    output_file.write("=" * 80 + "\n\n")
    output_file.write(songs_section)
    output_file.write("\n\n")
    
    # write featured in section
    output_file.write("=" * 80 + "\n")
    output_file.write("Section: Every album or playlist the song is featured in \n")
    output_file.write("=" * 80 + "\n\n")
    output_file.write(features_section)
    
    output_file.close()
    print("Created shazam_data.txt with multiple sections")

# run the function
create_sectioned_text_file()
# Out:
# Created shazam_data.txt with multiple sections
